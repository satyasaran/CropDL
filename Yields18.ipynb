# %%
import pandas as pd
import numpy as np

# %%
yield_data_18=pd.read_csv('./Dataset_Potato_18_20/Yield2018.csv').drop(columns=['Unnamed: 0'])

# %%
yield_data_18
# Out:
#      sample  row  bin  bed          ID      yield   yieldDM      Nconc  \
# 0         1  302    1    3     Desiree  46.776667  8.552578  10.459561
# 1         2  302    2    3     Desiree  35.462857  5.885217  14.868796
# 2         3  302    3    3   X96_BYM_8  30.396190  4.620471  12.563152
# 3         4  302    4    3   X96_BYM_8  41.256667  5.626157  14.132663
# 4         5  304    1    3        Cara  35.276667  6.482796  11.519757
# ..      ...  ...  ...  ...         ...        ...       ...        ...
# 107     428  597    4    4        Cara  37.103333  7.385776  11.480825
# 108     429  599    1    4  X05_GQE_02  35.515833  7.082659  10.493332
# 109     430  599    2    4  X05_GQE_02  31.586667  5.768146  12.747907
# 110     431  599    3    4   X96_BYM_8  52.647778  8.559105  10.439274
# 111     432  599    4    4   X96_BYM_8  24.766667  4.046128  11.924141
#
#     position  year  block
# 0      North  2018      2
# 1      North  2018      2
# 2      South  2018      2
# ...

# %%
idata=yield_data_18[['bin','bed','row','ID','position','yield','yieldDM']].copy()

# %%
idata
# Out:
#      bin  bed  row          ID position      yield   yieldDM
# 0      1    3  302     Desiree    North  46.776667  8.552578
# 1      2    3  302     Desiree    North  35.462857  5.885217
# 2      3    3  302   X96_BYM_8    South  30.396190  4.620471
# 3      4    3  302   X96_BYM_8    South  41.256667  5.626157
# 4      1    3  304        Cara    North  35.276667  6.482796
# ..   ...  ...  ...         ...      ...        ...       ...
# 107    4    4  597        Cara    South  37.103333  7.385776
# 108    1    4  599  X05_GQE_02    North  35.515833  7.082659
# 109    2    4  599  X05_GQE_02    North  31.586667  5.768146
# 110    3    4  599   X96_BYM_8    South  52.647778  8.559105
# 111    4    4  599   X96_BYM_8    South  24.766667  4.046128
#
# [112 rows x 7 columns]

# %%
Y#datap_T=idata[(idata['position']=='South')&(idata['bed']==3)| (idata['position']=='North')&(idata['bed']==4)]

# %%
idata_wet_sample=idata[(idata['bed']==3)&(idata['bin']==4)| (idata['bed']==4)&(idata['bin']==1)]

# %%
idata_wet_sample
# Out:
#      bin  bed  row          ID position      yield    yieldDM
# 3      4    3  302   X96_BYM_8    South  41.256667   5.626157
# 7      4    3  304     Aventra    South  44.891667  10.824987
# 11     4    3  306  X05_GQE_02    South  37.378333   6.613151
# 15     4    3  308       Agria    South  36.760833   6.336819
# 19     4    3  310        Cara    South  36.778333   6.327502
# 23     4    3  312   X89_BJQ_4    South  47.059167   8.353661
# 27     4    3  314     Desiree    South  51.663333   8.293126
# 31     4    3  316   X96_BYM_8    South  40.591667   5.909895
# 35     4    3  318     Desiree    South  52.345833   7.589862
# 39     4    3  320        Cara    South  35.470833   5.947413
# 43     4    3  322   X89_BJQ_4    South  45.230000   8.553751
# 47     4    3  324       Agria    South  33.208333   6.268893
# 51     4    3  326  X05_GQE_02    South  33.172500   5.542783
# 55     4    3  328     Aventra    South  37.259167   8.130689
# ...

# %%
idata_dry_sample=idata[(idata['bed']==3)&(idata['bin']==3)| (idata['bed']==4)&(idata['bin']==2)]

# %%
idata_dry_sample
# Out:
#      bin  bed  row          ID position      yield   yieldDM
# 2      3    3  302   X96_BYM_8    South  30.396190  4.620471
# 6      3    3  304     Aventra    South  31.700952  7.900819
# 10     3    3  306  X05_GQE_02    South  29.668571  5.622899
# 14     3    3  308       Agria    South  29.606667  5.245840
# 18     3    3  310        Cara    South  25.018095  4.230474
# 22     3    3  312   X89_BJQ_4    South  27.870476  4.239662
# 26     3    3  314     Desiree    South  37.504762  5.934992
# 30     3    3  316   X96_BYM_8    South  29.778095  5.230613
# 34     3    3  318     Desiree    South  42.790476  6.778793
# 38     3    3  320        Cara    South  27.005714  5.100540
# 42     3    3  322   X89_BJQ_4    South  35.682857  6.122789
# 46     3    3  324       Agria    South  22.575238  4.138554
# 50     3    3  326  X05_GQE_02    South  27.672381  5.246178
# 54     3    3  328     Aventra    South  28.811429  7.254176
# ...

# %%
RL=pd.read_csv('SquareRL_2018.csv').drop(columns=['Unnamed: 0'])

# %%
RL
# Out:
#     RL_June_SD_(37, 56]  RL_June_SD_(56, 75]  RL_June_SD_(75, 94]  \
# 0              0.263105             0.457308             0.274402
# 1              0.946920             1.142678             0.323073
# 2              1.621167             0.799662             0.135740
# 3              0.824641             0.590553             0.333487
# 4              0.997321             1.192406             0.311265
# 5              0.820696             0.872357             0.228022
# 6              0.959610             1.041878             0.259099
# 7              1.449577             0.575709             0.295029
# 8              0.913714             0.962656             0.251559
# 9              0.853634             0.815584             0.206826
# 10             0.616396             0.915719             0.329843
# 11             0.598584             0.476049             0.152353
# 12             0.740990             0.449623             0.331905
# ...

# %%
pd.merge(idata_dry_sample,RL,on='row').to_csv('SQRL_Dry_Yields_average_tube_2018.csv')
pd.merge(idata_wet_sample,RL,on='row').to_csv('SQRL_Wet_Yields_average_tube_2018.csv')

# %%
RL_yields_Dry=pd.merge(idata_dry_sample,RL,on='row')
RL_yields_Wet=pd.merge(idata_wet_sample,RL,on='row')

# %%
RL_yields_Dry
# Out:
#     bin  bed  row          ID position      yield   yieldDM  \
# 0     3    3  302   X96_BYM_8    South  30.396190  4.620471
# 1     3    3  304     Aventra    South  31.700952  7.900819
# 2     3    3  306  X05_GQE_02    South  29.668571  5.622899
# 3     3    3  308       Agria    South  29.606667  5.245840
# 4     3    3  310        Cara    South  25.018095  4.230474
# 5     3    3  312   X89_BJQ_4    South  27.870476  4.239662
# 6     3    3  314     Desiree    South  37.504762  5.934992
# 7     3    3  316   X96_BYM_8    South  29.778095  5.230613
# 8     3    3  318     Desiree    South  42.790476  6.778793
# 9     3    3  320        Cara    South  27.005714  5.100540
# 10    3    3  322   X89_BJQ_4    South  35.682857  6.122789
# 11    3    3  324       Agria    South  22.575238  4.138554
# 12    3    3  326  X05_GQE_02    South  27.672381  5.246178
# 13    3    3  328     Aventra    South  28.811429  7.254176
# 14    2    4  573        Cara    North  26.495556  4.952361
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
RL_table_main_Wet=RL_yields_Wet.drop(['row','bin','bed','ID','position'], axis=1)
RL_table_main_Dry=RL_yields_Dry.drop(['row','bin','bed','ID','position'], axis=1)

# %%
RL_table_main_Wet
# Out:
#         yield    yieldDM  RL_June_SD_(37, 56]  RL_June_SD_(56, 75]  \
# 0   41.256667   5.626157             0.263105             0.457308
# 1   44.891667  10.824987             0.946920             1.142678
# 2   37.378333   6.613151             1.621167             0.799662
# 3   36.760833   6.336819             0.824641             0.590553
# 4   36.778333   6.327502             0.997321             1.192406
# 5   47.059167   8.353661             0.820696             0.872357
# 6   51.663333   8.293126             0.959610             1.041878
# 7   40.591667   5.909895             1.449577             0.575709
# 8   52.345833   7.589862             0.913714             0.962656
# 9   35.470833   5.947413             0.853634             0.815584
# 10  45.230000   8.553751             0.616396             0.915719
# 11  33.208333   6.268893             0.598584             0.476049
# 12  33.172500   5.542783             0.740990             0.449623
# ...

# %%
RL_table_main_Wet['TRL']=RL_table_main_Wet.iloc[:,2:].sum(axis=1)
RL_table_main_Dry['TRL']=RL_table_main_Dry.iloc[:,2:].sum(axis=1)

# %%
RL_table_main_Wet['TRL_June']=RL_table_main_Wet.filter(regex='June').sum(axis=1)
RL_table_main_Wet['TRL_July']=RL_table_main_Wet.filter(regex='July').sum(axis=1)
RL_table_main_Wet['TRL_Aug']=RL_table_main_Wet.filter(regex='Aug').sum(axis=1)

RL_table_main_Dry['TRL_June']=RL_table_main_Dry.filter(regex='June').sum(axis=1)
RL_table_main_Dry['TRL_July']=RL_table_main_Dry.filter(regex='July').sum(axis=1)
RL_table_main_Dry['TRL_Aug']=RL_table_main_Dry.filter(regex='Aug').sum(axis=1)

# %%
# Removing columns containg zeros
RL_table_main_Dry=RL_table_main_Dry.replace(0,np.nan).dropna(axis=1,how="all")
RL_table_main_Wet=RL_table_main_Wet.replace(0,np.nan).dropna(axis=1,how="all")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(RL_table_main_Wet.corr(), dtype=np.bool))
heatmap = sns.heatmap(RL_table_main_Wet.corr(), mask=mask, vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Yields (Wet: bed 3, bin 4; bed 4, bin 1) and Square Root lengths in 2018', fontdict={'fontsize':18}, pad=16);
plt.savefig('Corr_RL_Wet_yields_2018.png')
# Out:
# /tmp/ipykernel_11167/565823677.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(RL_table_main_Wet.corr(), dtype=np.bool))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(RL_table_main_Dry.corr(), dtype=np.bool))
heatmap = sns.heatmap(RL_table_main_Dry.corr(), mask=mask, vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Yields (Dry: bed 3, bin 3; bed 4, bin 2) and Square Root lengths in 2018', fontdict={'fontsize':18}, pad=16);
plt.savefig('Corr_RL_Dry_yields_2018.png')
# Out:
# /tmp/ipykernel_11167/3128128091.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(RL_table_main_Dry.corr(), dtype=np.bool))

# %%
RL_table_main_Dry
# Out:
#         yield   yieldDM  RL_June_SD_(49, 59]  RL_June_SD_(59, 70]  \
# 0   30.396190  4.620471             0.391500             0.390000
# 1   31.700952  7.900819             1.664000             3.387500
# 2   29.668571  5.622899             3.140682             1.704242
# 3   29.606667  5.245840             1.632000             0.589583
# 4   25.018095  4.230474             3.473000             3.750417
# 5   27.870476  4.239662             2.304500             1.295833
# 6   37.504762  5.934992             2.027000             2.985000
# 7   29.778095  5.230613             3.663909             0.245947
# 8   42.790476  6.778793             2.004500             1.937917
# 9   27.005714  5.100540             2.888000             1.113333
# 10  35.682857  6.122789             0.968500             2.630833
# 11  22.575238  4.138554             0.603000             0.518333
# 12  27.672381  5.246178             1.069500             0.494167
# ...
